# %%
# get files from drive
import shutil
from pathlib import Path

shutil.copytree(Path(r'/content/drive/MyDrive/Colab files/traffic classifier detector'), Path(r'/content/yolov7'))
# Out:
# PosixPath('/content/yolov7')

# %%
# !python /content/yolov7/detect_and_classify.py --weights /content/yolov7/runs/train/yolov72/weights/last.pt --conf 0.25 --img-size 415 --source /content/test1.jpg
# !python /content/yolov7/detect_and_classify.py --weights /content/yolov7/runs/train/yolov72/weights/last.pt --conf 0.25 --img-size 415 --source /content/test5.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=415, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/test1.jpg', update=False, view_img=False, weights=['/content/yolov7/runs/train/yolov72/weights/last.pt'])
# 2022-10-03 15:14:14.147366: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# WARNING: --img-size 415 must be multiple of max stride 32, updating to 416
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
#display the detected images

import cv2
from google.colab.patches import cv2_imshow
def show_image(path):
  image = cv2.imread(path)
  cv2_imshow(image)

show_image("/content/runs/detect/exp6/test1.jpg")
show_image("/content/runs/detect/exp7/test5.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x512 at 0x7F0C28041A90>
# <PIL.Image.Image image mode=RGB size=500x278 at 0x7F0C280411D0>
